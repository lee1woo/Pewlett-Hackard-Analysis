# %%
import pandas as pd

# %%
employee_df = pd.read_csv("Data/employees.csv")

# %%
employee_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
title_df = pd.read_csv("Data/titles.csv")

# %%
title_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
df = pd.merge(employee_df, title_df, on=["emp_no"])
df["title"].value_counts()
# Out:
# Engineer              115003
# Staff                 107391
# Senior Engineer        97750
# Senior Staff           92853
# Technique Leader       15159
# Assistant Engineer     15128
# Manager                   24
# Name: title, dtype: int64

# %%
df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %%
df["birth_date"] = pd.to_datetime(df["birth_date"])

# %%
df.head()
# Out:
#    emp_no birth_date first_name last_name gender   hire_date            title  \
# 0   10001 1953-09-02     Georgi   Facello      M  1986-06-26  Senior Engineer
# 1   10002 1964-06-02    Bezalel    Simmel      F  1985-11-21            Staff
# 2   10003 1959-12-03      Parto   Bamford      M  1986-08-28  Senior Engineer
# 3   10004 1954-05-01  Chirstian   Koblick      M  1986-12-01         Engineer
# 4   10004 1954-05-01  Chirstian   Koblick      M  1986-12-01  Senior Engineer
#
#     from_date     to_date
# 0  1986-06-26  9999-01-01
# 1  1996-08-03  9999-01-01
# 2  1995-12-03  9999-01-01
# 3  1986-12-01  1995-12-01
# 4  1995-12-01  9999-01-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443308 entries, 0 to 443307
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      443308 non-null  int64
#  1   birth_date  443308 non-null  datetime64[ns]
#  2   first_name  443308 non-null  object
#  3   last_name   443308 non-null  object
#  4   gender      443308 non-null  object
#  5   hire_date   443308 non-null  object
#  6   title       443308 non-null  object
#  7   from_date   443308 non-null  object
#  8   to_date     443308 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 33.8+ MB

# %%
retirement_title_df = df.loc[:,(df["birth_date"]>= '1952-01-01') & (df["birth_date"]<= '1955-12-31')]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# /var/folders/b4/vxqwhp0n4gdc5919s_1vf7740000gn/T/ipykernel_54884/3855336532.py in <module>
# ----> 1 retirement_title_df = df.loc[:,(df["birth_date"]>= '1952-01-01') & (df["birth_date"]<= '1955-12-31')]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# ...
